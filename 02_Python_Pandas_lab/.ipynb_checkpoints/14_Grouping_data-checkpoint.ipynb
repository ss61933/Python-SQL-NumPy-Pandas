# %%
import pandas as pd

# %%
pdata=pd.read_csv("sales_data_sample-original.csv",encoding='latin1')

# %%
pdata.iloc[0:3,0:3]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH
# 0        10107               30      95.70
# 1        10121               34      81.35
# 2        10134               41      94.74

# %%
pdata["COUNTRY"].nunique()
# Out:
# 19

# %%
# Now lets try to put data  in different bucktets as per country value

# %%
usa_group=pdata[pdata["COUNTRY"]=="USA"]
france_group=pdata[pdata["COUNTRY"]=="FRANCE"]
india_group=pdata[pdata["COUNTRY"]=="INDIA"]

# %%
#So above we will have t create n number of groups manually .

# %%
# Instead we can use below method
group_country=pdata.groupby("COUNTRY")

# %%
group_country.get_group("USA")
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# 5           10168               36      96.66                1  3479.76
# 8           10201               22      98.57                2  2168.54
# ...           ...              ...        ...              ...      ...
# 2804        10185               28      64.43                6  1804.04
# 2807        10222               36      63.34               18  2280.24
# 2809        10248               23      65.52                9  1506.96
# 2817        10337               42      97.16                5  4080.72
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
type(group_country)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
type(group_country.get_group("USA"))
# Out:
# pandas.core.frame.DataFrame

# %%
#number of elements in any group
len(group_country.get_group("USA"))
# Out:
# 1004

# %%
group_country.size()  # Size of each group
# Out:
# COUNTRY
# Australia       185
# Austria          55
# Belgium          33
# Canada           70
# Denmark          63
# Finland          92
# France          314
# Germany          62
# Ireland          16
# Italy           113
# Japan            52
# Norway           85
# Philippines      26
# Singapore        79
# Spain           342
# Sweden           57
# Switzerland      31
# UK              144
# USA            1004
# dtype: int64

# %%
group_country.first()  ##Returns first row of each group
# Out:
#              ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# COUNTRY
# Australia          10223               37     100.00                1
# Austria            10341               41     100.00                9
# Belgium            10273               30     100.00                4
# Canada             10206               47     100.00                6
# Denmark            10105               50     100.00                2
# Finland            10299               23     100.00                9
# France             10121               34      81.35                5
# Germany            10191               21     100.00                3
# Ireland            10220               32     100.00                2
# Italy              10280               34     100.00                2
# Japan              10258               32     100.00                6
# Norway             10188               48     100.00                1
# ...

# %%
  group_country.last()
# Out:
#              ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# COUNTRY
# Australia          10415               42      57.61                3
# Austria            10119               28      48.17                6
# Belgium            10273               37      45.86               10
# Canada             10283               33      51.32               12
# Denmark            10327               37      86.74                4
# Finland            10373               29     100.00                1
# France             10397               34      62.24                1
# Germany            10296               21      45.19               10
# Ireland            10297               35     100.00                3
# Italy              10293               32      60.06                1
# Japan              10339               27      76.31                6
# Norway             10284               32      64.41                9
# ...

# %%
group_country.get_group("USA").sum()
# Out:
# C:\Users\swapnil\AppData\Local\Temp\ipykernel_9584\583874036.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   group_country.get_group("USA").sum()
# ORDERNUMBER                                                  10297362
# QUANTITYORDERED                                                 35659
# PRICEEACH                                                    84159.65
# ORDERLINENUMBER                                                  6369
# SALES                                                      3627982.83
# ORDERDATE           2/24/2003 0:008/25/2003 0:0010/10/2003 0:0010/...
# STATUS              ShippedShippedShippedShippedShippedShippedShip...
# QTR_ID                                                           2814
# MONTH_ID                                                         7380
# ...

# %%
group_country.get_group("USA").sum()["SALES"]
# Out:
# C:\Users\swapnil\AppData\Local\Temp\ipykernel_9584\3299531364.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   group_country.get_group("USA").sum()["SALES"]
# 3627982.83

# %%
group_country.sum()
# Out:
#              ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# COUNTRY
# Australia        1898841             6246   15449.14             1181
# Austria           564648             1974    4759.16              320
# Belgium           339687             1074    2887.31              164
# Canada            719223             2293    5957.05              415
# Denmark           644467             2197    5503.89              399
# Finland           944808             3192    7722.15              587
# France           3223513            11090   25920.87             2028
# Germany           636423             2148    5184.30              388
# Ireland           164059              490    1377.98               73
# Italy            1158239             3773    9329.40              890
# Japan             535018             1842    4290.26              362
# Norway            869325             2842    7318.18              559
# ...

# %%
group_country.max()["SALES"]
# Out:
# C:\Users\swapnil\AppData\Local\Temp\ipykernel_9584\2330202861.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   group_country.max()["SALES"]
# COUNTRY
# Australia       9774.03
# Austria         9240.00
# Belgium         6804.63
# Canada          9064.89
# Denmark        10468.90
# Finland        10606.20
# France         11739.70
# Germany         8940.96
# Ireland         8258.00
# Italy           9160.36
# Japan          10758.00
# Norway          8844.12
# Philippines     7483.98
# Singapore      10993.50
# Spain          12001.00
# Sweden          7209.11
# Switzerland     6761.60
# UK             11886.60
# USA            14082.80
# Name: SALES, dtype: float64

# %%
group_country.get_group("USA").mean()["SALES"]
# Out:
# C:\Users\swapnil\AppData\Local\Temp\ipykernel_9584\2559802450.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   group_country.get_group("USA").mean()["SALES"]
# 3613.5287151394423

# %%
group_country.get_group("USA").min()["DEALSIZE"]
# Out:
# C:\Users\swapnil\AppData\Local\Temp\ipykernel_9584\3749939505.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   group_country.get_group("USA").min()["DEALSIZE"]
# 'Large'

# %%
group_country.get_group("USA").max()["DEALSIZE"]
# Out:
# C:\Users\swapnil\AppData\Local\Temp\ipykernel_9584\3554019909.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   group_country.get_group("USA").max()["DEALSIZE"]
# 'Small'

# %%
group_country.get_group("USA").nunique()["DEALSIZE"]
# Out:
# 3

# %%
type(group_country.get_group("USA"))
# Out:
# pandas.core.frame.DataFrame

# %%
us_grop=group_country.get_group("USA")

# %%
us_grop["DEALSIZE"].unique()
# Out:
# array(['Small', 'Medium', 'Large'], dtype=object)

# %%
us_grop["DEALSIZE"].nunique()
# Out:
# 3

# %%
##Agg method

# %%
group_country.agg('sum')
# Out:
#              ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# COUNTRY
# Australia        1898841             6246   15449.14             1181
# Austria           564648             1974    4759.16              320
# Belgium           339687             1074    2887.31              164
# Canada            719223             2293    5957.05              415
# Denmark           644467             2197    5503.89              399
# Finland           944808             3192    7722.15              587
# France           3223513            11090   25920.87             2028
# Germany           636423             2148    5184.30              388
# Ireland           164059              490    1377.98               73
# Italy            1158239             3773    9329.40              890
# Japan             535018             1842    4290.26              362
# Norway            869325             2842    7318.18              559
# ...

# %%
group_country.agg('min')["SALES"]
# Out:
# C:\Users\swapnil\AppData\Local\Temp\ipykernel_9584\327170629.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   group_country.agg('min')["SALES"]
# COUNTRY
# Australia       652.35
# Austria         640.05
# Belgium         881.40
# Canada         1119.93
# Denmark        1146.50
# Finland         891.03
# France          482.13
# Germany         948.99
# Ireland        1056.40
# Italy           577.60
# Japan           553.95
# Norway         1129.04
# Philippines    1173.15
# Singapore       785.64
# Spain           683.80
# Sweden         1467.48
# Switzerland    1205.04
# UK              710.20
# USA             541.14
# Name: SALES, dtype: float64

# %%
group_country.agg('min')[["SALES","ORDERLINENUMBER"]]
# Out:
# C:\Users\swapnil\AppData\Local\Temp\ipykernel_9584\2903764488.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   group_country.agg('min')[["SALES","ORDERLINENUMBER"]]
#                SALES  ORDERLINENUMBER
# COUNTRY
# Australia     652.35                1
# Austria       640.05                1
# Belgium       881.40                1
# Canada       1119.93                1
# Denmark      1146.50                1
# Finland       891.03                1
# France        482.13                1
# Germany       948.99                1
# Ireland      1056.40                1
# Italy         577.60                1
# Japan         553.95                1
# Norway       1129.04                1
# Philippines  1173.15                1
# Singapore     785.64                1
# Spain         683.80                1
# ...

# %%
group_country.get_group("USA")["SALES"]==652.35
# Out:
# 0       False
# 3       False
# 4       False
# 5       False
# 8       False
#         ...
# 2804    False
# 2807    False
# 2809    False
# 2817    False
# 2822    False
# Name: SALES, Length: 1004, dtype: bool

# %%
#agg function is useful when u wnat multiple

# %%
group_country.agg(['sum','min'])[["SALES","ORDERLINENUMBER"]]
# Out:
# C:\Users\swapnil\AppData\Local\Temp\ipykernel_9584\1483993836.py:1: FutureWarning: ['ADDRESSLINE2', 'STATE', 'POSTALCODE'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   group_country.agg(['sum','min'])[["SALES","ORDERLINENUMBER"]]
#                   SALES          ORDERLINENUMBER
#                     sum      min             sum min
# COUNTRY
# Australia     630623.10   652.35            1181   1
# Austria       202062.53   640.05             320   1
# Belgium       108412.62   881.40             164   1
# Canada        224078.56  1119.93             415   1
# Denmark       245637.15  1146.50             399   1
# Finland       329581.91   891.03             587   1
# France       1110916.52   482.13            2028   1
# Germany       220472.09   948.99             388   1
# Ireland        57756.43  1056.40              73   1
# ...

# %%
req={"ORDERLINENUMBER":'mean',"SALES":'sum'} # So here we defined which type of aggregation is needed for which column

# %%
group_country.agg(req)
# Out:
#              ORDERLINENUMBER       SALES
# COUNTRY
# Australia           6.383784   630623.10
# Austria             5.818182   202062.53
# Belgium             4.969697   108412.62
# Canada              5.928571   224078.56
# Denmark             6.333333   245637.15
# Finland             6.380435   329581.91
# France              6.458599  1110916.52
# Germany             6.258065   220472.09
# Ireland             4.562500    57756.43
# Italy               7.876106   374674.31
# Japan               6.961538   188167.81
# Norway              6.576471   307463.70
# Philippines         6.423077    94015.73
# Singapore           6.886076   288488.41
# Spain               6.391813  1215686.92
# Sweden              5.912281   210014.21
# Switzerland         8.322581   117713.56
# UK                  7.131944   478880.46
# USA                 6.343625  3627982.83
