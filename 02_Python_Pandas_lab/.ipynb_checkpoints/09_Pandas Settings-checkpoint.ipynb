# %%
# %%HTML
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border-style: solid;
#         border-width: thin;
#     }
# </style>
# Out:
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border-style: solid;
#         border-width: thin;
#     }
# </style>

# %% [markdown]
# # Pandas Options

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/options.html

# %% [markdown]
# ## Max_rows, Max_columns

# %%
import pandas as pd
df = pd.read_csv('googleplaystore.csv')

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
pd.options.display.max_columns =  3
pd.options.display.max_rows = 8

# %%
df
# Out:
#                                                      App  ...  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...
# 1                                    Coloring book moana  ...
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...
# 3                                  Sketch - Draw & Paint  ...
# ...                                                  ...  ...
# 10837                   Fr. Mike Schmitz Audio Teachings  ...
# 10838                             Parkinson Exercices FR  ...
# 10839                      The SCP Foundation DB fr nn5n  ...
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# ...                   ...
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10841 rows x 13 columns]

# %%
pd.options.display.max_columns
# Out:
# 3

# %%
pd.reset_option('max_rows')

# %%
pd.options.display.max_columns
# Out:
# 3

# %%
df
# Out:
#                                                      App  ...  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...
# 1                                    Coloring book moana  ...
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...
# 3                                  Sketch - Draw & Paint  ...
# 4                  Pixel Draw - Number Art Coloring Book  ...
# ...                                                  ...  ...
# 10836                                   Sya9a Maroc - FR  ...
# 10837                   Fr. Mike Schmitz Audio Teachings  ...
# 10838                             Parkinson Exercices FR  ...
# 10839                      The SCP Foundation DB fr nn5n  ...
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10841 rows x 13 columns]

# %%
pd.options.display.max_columns =  10

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size  ... Content Rating  \
# 0         4.1     159                 19M  ...       Everyone
# 1         3.9     967                 14M  ...       Everyone
# 2         4.7   87510                8.7M  ...       Everyone
# 3         4.5  215644                 25M  ...           Teen
# 4         4.3     967                2.8M  ...       Everyone
# ...       ...     ...                 ...  ...            ...
# 10836     4.5      38                 53M  ...       Everyone
# 10837     5.0       4                3.6M  ...       Everyone
# 10838     NaN       3                9.5M  ...       Everyone
# 10839     4.5     114  Varies with device  ...     Mature 17+
# 10840     4.5  398307                 19M  ...       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
# ...                          ...               ...                 ...
# 10836                  Education     July 25, 2017                1.48
# 10837                  Education      July 6, 2018                 1.0
# 10838                    Medical  January 20, 2017                 1.0
# 10839          Books & Reference  January 19, 2015  Varies with device
# 10840                  Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10841 rows x 13 columns]

# %%
pd.describe_option('max_rows')
# Out:
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: 60]
# styler.render.max_rows : int, optional
#     The maximum number of rows that will be rendered. May still be reduced to
#     satsify ``max_elements``, which takes precedence.
#     [default: None] [currently: None]

# %%
pd.set_option('display.max_rows', 10)

# %%
pd.options.display.max_rows
# Out:
# 10

# %%
pd.get_option('display.max_rows')
# Out:
# 10

# %% [markdown]
# ## Precision -for float number

# %%
pd.options.display.precision
# Out:
# 6

# %%
import numpy as np

# %%
pdf = pd.DataFrame(np.random.randn(5,5))

# %%
pdf
# Out:
#           0         1         2         3         4
# 0  0.428027  0.294667 -1.586086  0.206972  0.056736
# 1  0.449714  0.715545 -0.003347  0.215033  0.290690
# 2  0.552276 -0.776639 -0.945684 -1.694927  0.151698
# 3  3.190984 -0.940572  0.993692 -0.031902  0.918311
# 4 -1.364842 -0.486277 -1.794451  1.097950  0.675381

# %%
pd.options.display.precision = 3

# %%
pdf
# Out:
#        0      1      2      3      4
# 0  0.428  0.295 -1.586  0.207  0.057
# 1  0.450  0.716 -0.003  0.215  0.291
# 2  0.552 -0.777 -0.946 -1.695  0.152
# 3  3.191 -0.941  0.994 -0.032  0.918
# 4 -1.365 -0.486 -1.794  1.098  0.675

# %%
pd.options.display.precision = 6

# %%
pdf
# Out:
#           0         1         2         3         4
# 0  0.428027  0.294667 -1.586086  0.206972  0.056736
# 1  0.449714  0.715545 -0.003347  0.215033  0.290690
# 2  0.552276 -0.776639 -0.945684 -1.694927  0.151698
# 3  3.190984 -0.940572  0.993692 -0.031902  0.918311
# 4 -1.364842 -0.486277 -1.794451  1.097950  0.675381

# %%
pd.get_option('display.precision')
# Out:
# 6

# %%
## When you move from high preceision to low and come back to high , you wont miss the data , it display exact data with actual precision
