# %% [markdown]
# # Import Time Series Data

# %%
import pandas as pd

# %%
pr=pd.read_csv('RestaurantVisitors.csv',index_col='date',parse_dates=['date'])

# %%
pr
# Out:
#               weekday  holiday    holiday_name  rest1  rest2  rest3  rest4  \
# date
# 2016-01-01     Friday        1  New Year's Day   65.0   25.0   67.0  139.0
# 2016-01-02   Saturday        0              na   24.0   39.0   43.0   85.0
# 2016-01-03     Sunday        0              na   24.0   31.0   66.0   81.0
# 2016-01-04     Monday        0              na   23.0   18.0   32.0   32.0
# 2016-01-05    Tuesday        0              na    2.0   15.0   38.0   43.0
# ...               ...      ...             ...    ...    ...    ...    ...
# 2017-05-27   Saturday        0              na    NaN    NaN    NaN    NaN
# 2017-05-28     Sunday        0              na    NaN    NaN    NaN    NaN
# 2017-05-29     Monday        1    Memorial Day    NaN    NaN    NaN    NaN
# 2017-05-30    Tuesday        0              na    NaN    NaN    NaN    NaN
# 2017-05-31  Wednesday        0              na    NaN    NaN    NaN    NaN
#
#             total
# date
# 2016-01-01  296.0
# ...

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 517 entries, 2016-01-01 to 2017-05-31
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   weekday       517 non-null    object
#  1   holiday       517 non-null    int64
#  2   holiday_name  517 non-null    object
#  3   rest1         478 non-null    float64
#  4   rest2         478 non-null    float64
#  5   rest3         478 non-null    float64
#  6   rest4         478 non-null    float64
#  7   total         478 non-null    float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 36.4+ KB

# %%
pr.index
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                '2016-01-09', '2016-01-10',
#                ...
#                '2017-05-22', '2017-05-23', '2017-05-24', '2017-05-25',
#                '2017-05-26', '2017-05-27', '2017-05-28', '2017-05-29',
#                '2017-05-30', '2017-05-31'],
#               dtype='datetime64[ns]', name='date', length=517, freq=None)

# %%
pr.columns
# Out:
# Index(['weekday', 'holiday', 'holiday_name', 'rest1', 'rest2', 'rest3',
#        'rest4', 'total'],
#       dtype='object')

# %%
pr.drop(labels=['weekday', 'holiday', 'holiday_name','total'], axis=1,inplace=True)

# %%
pr.head(2) #so we have total number of visitors each day
# Out:
#             rest1  rest2  rest3  rest4
# date
# 2016-01-01   65.0   25.0   67.0  139.0
# 2016-01-02   24.0   39.0   43.0   85.0

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 517 entries, 2016-01-01 to 2017-05-31
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rest1   478 non-null    float64
#  1   rest2   478 non-null    float64
#  2   rest3   478 non-null    float64
#  3   rest4   478 non-null    float64
# dtypes: float64(4)
# memory usage: 36.4 KB

# %%
pr.describe()
# Out:
#             rest1       rest2       rest3       rest4
# count  478.000000  478.000000  478.000000  478.000000
# mean    37.533473   27.163180   31.548117   37.548117
# std     21.499791   15.731851   17.820112   24.614955
# min      1.000000    1.000000    6.000000    3.000000
# 25%     22.250000   15.000000   18.000000   19.000000
# 50%     33.000000   25.000000   24.000000   30.000000
# 75%     49.000000   38.000000   45.000000   50.000000
# max    128.000000   91.000000   99.000000  139.000000

# %%
pr["rest1"]
# Out:
# date
# 2016-01-01    65.0
# 2016-01-02    24.0
# 2016-01-03    24.0
# 2016-01-04    23.0
# 2016-01-05     2.0
#               ...
# 2017-05-27     NaN
# 2017-05-28     NaN
# 2017-05-29     NaN
# 2017-05-30     NaN
# 2017-05-31     NaN
# Name: rest1, Length: 517, dtype: float64

# %%
# %matplotlib inline

# %%
pr["rest1"].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#here we have datetime index  object and hence xais is displaying individual date

# %% [markdown]
# # Indexing and slicing

# %%
pr.iloc[0]
# Out:
# rest1     65.0
# rest2     25.0
# rest3     67.0
# rest4    139.0
# Name: 2016-01-01 00:00:00, dtype: float64

# %%
pr.iloc[0,3] #4th information info
# Out:
# 139.0

# %%
pr.iloc[0,1:3] # get me 1st and 2nd rest info from fist row
# Out:
# rest2    25.0
# rest3    67.0
# Name: 2016-01-01 00:00:00, dtype: float64

# %%
#fetch data from 2016 year, remember here index is date object and not a string

# %%
pr.loc['2016']
# Out:
#             rest1  rest2  rest3  rest4
# date
# 2016-01-01   65.0   25.0   67.0  139.0
# 2016-01-02   24.0   39.0   43.0   85.0
# 2016-01-03   24.0   31.0   66.0   81.0
# 2016-01-04   23.0   18.0   32.0   32.0
# 2016-01-05    2.0   15.0   38.0   43.0
# ...           ...    ...    ...    ...
# 2016-12-27   38.0   56.0   19.0   11.0
# 2016-12-28   31.0   53.0   36.0   24.0
# 2016-12-29   33.0   19.0   27.0   43.0
# 2016-12-30   64.0   49.0   24.0   59.0
# 2016-12-31   88.0   54.0   57.0  117.0
#
# [366 rows x 4 columns]

# %%
pr.loc['2017-01-01':'2017-01-03']
# Out:
#             rest1  rest2  rest3  rest4
# date
# 2017-01-01   48.0   43.0   47.0  118.0
# 2017-01-02    7.0    5.0   43.0   75.0
# 2017-01-03   39.0   34.0   16.0   55.0

# %%
pr.loc['2017-01-01':'2017-01-03']["rest1"]
# Out:
# date
# 2017-01-01    48.0
# 2017-01-02     7.0
# 2017-01-03    39.0
# Name: rest1, dtype: float64

# %%
pr.loc['2017-01-01':'2017-01-03'][["rest1","rest2"]]
# Out:
#             rest1  rest2
# date
# 2017-01-01   48.0   43.0
# 2017-01-02    7.0    5.0
# 2017-01-03   39.0   34.0

# %%
pr.loc['2017-01-01':'2017-01-03',"rest1":"rest4"]
# Out:
#             rest1  rest2  rest3  rest4
# date
# 2017-01-01   48.0   43.0   47.0  118.0
# 2017-01-02    7.0    5.0   43.0   75.0
# 2017-01-03   39.0   34.0   16.0   55.0

# %%
#get the data for 2017 1st month
pr.loc['2017-01']
# Out:
#             rest1  rest2  rest3  rest4
# date
# 2017-01-01   48.0   43.0   47.0  118.0
# 2017-01-02    7.0    5.0   43.0   75.0
# 2017-01-03   39.0   34.0   16.0   55.0
# 2017-01-04   23.0   24.0   23.0   29.0
# 2017-01-05   14.0   22.0   28.0   11.0
# 2017-01-06   16.0   33.0   21.0   21.0
# 2017-01-07   85.0   58.0   39.0   51.0
# 2017-01-08   27.0   17.0   43.0   85.0
# 2017-01-09   40.0   11.0   10.0   30.0
# 2017-01-10   12.0   25.0   18.0   14.0
# 2017-01-11   19.0   17.0   12.0   14.0
# 2017-01-12   21.0   27.0   16.0   15.0
# 2017-01-13   30.0   47.0   16.0    9.0
# 2017-01-14   84.0   48.0   55.0   39.0
# 2017-01-15   33.0   35.0   51.0   39.0
# 2017-01-16   56.0   26.0   29.0   26.0
# 2017-01-17   38.0   27.0   19.0   19.0
# 2017-01-18   37.0   26.0   25.0   12.0
# 2017-01-19   23.0   19.0   19.0    9.0
# 2017-01-20   40.0   42.0   22.0   21.0
# 2017-01-21   63.0   25.0   57.0   37.0
# 2017-01-22   38.0   15.0   49.0   44.0
# 2017-01-23   18.0    4.0   24.0   16.0
# ...

# %% [markdown]
# # Resampling

# %%
#How many visiors we have for res1 in 2017?

# %%
#Similarly getting count of records based on quarter,month,year etc is resapmling

# %%
pr1=pr.resample("A")

# %%
pr1

# %%
pr1.min()
# Out:
#             rest1  rest2  rest3  rest4
# date
# 2016-12-31    1.0    1.0    6.0    4.0
# 2017-12-31    4.0    2.0    7.0    3.0

# %%
pr1.sum() #total visiors for each res
# Out:
#               rest1    rest2    rest3    rest4
# date
# 2016-12-31  13366.0  10002.0  11485.0  14250.0
# 2017-12-31   4575.0   2982.0   3595.0   3698.0

# %%
pr1.mean()
# Out:
#                 rest1      rest2      rest3      rest4
# date
# 2016-12-31  36.519126  27.327869  31.379781  38.934426
# 2017-12-31  40.848214  26.625000  32.098214  33.017857

# %%
pr1.plot()
# Out:
#                                            rest1  \
# date
# 2016-12-31  AxesSubplot(0.125,0.125;0.775x0.755)
# 2017-12-31  AxesSubplot(0.125,0.125;0.775x0.755)
#
#                                            rest2  \
# date
# 2016-12-31  AxesSubplot(0.125,0.125;0.775x0.755)
# 2017-12-31  AxesSubplot(0.125,0.125;0.775x0.755)
#
#                                            rest3  \
# date
# 2016-12-31  AxesSubplot(0.125,0.125;0.775x0.755)
# 2017-12-31  AxesSubplot(0.125,0.125;0.775x0.755)
#
#                                            rest4
# date
# 2016-12-31  AxesSubplot(0.125,0.125;0.775x0.755)
# 2017-12-31  AxesSubplot(0.125,0.125;0.775x0.755)

# %%
pr1.mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#So above is example of time series analysis

# %%
pr['2016-01'].sum()  #Sum of visitors for each restaurant for 1st month 2016
# Out:
# C:\Users\swapnil\AppData\Local\Temp\ipykernel_3112\3393463105.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   pr['2016-01'].sum()  #Sum of visitors for each restaurant for 1st month 2016
# rest1     920.0
# rest2     916.0
# rest3    1033.0
# rest4    1577.0
# dtype: float64

# %%
#quarter basis analysis

# %%
pr.resample("Q")

# %%
pr1=pr.resample("Q")

# %%
pr1

# %%
pr1.sum() #So here it retruns last day of quarter and agg along with it
# Out:
#              rest1   rest2   rest3   rest4
# date
# 2016-03-31  3206.0  2523.0  3070.0  4486.0
# 2016-06-30  3309.0  2203.0  2708.0  3481.0
# 2016-09-30  3346.0  2274.0  2869.0  3014.0
# 2016-12-31  3505.0  3002.0  2838.0  3269.0
# 2017-03-31  3579.0  2481.0  2878.0  2858.0
# 2017-06-30   996.0   501.0   717.0   840.0

# %%
#so rest 1 is doing better

# %%
pr.resample("M")

# %%
pr.resample("M").sum().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
weekly=pr.resample("W")

# %%
weekly.agg(["sum","mean"])
# Out:
#             rest1             rest2             rest3             rest4  \
#               sum       mean    sum       mean    sum       mean    sum
# date
# 2016-01-03  113.0  37.666667   95.0  31.666667  176.0  58.666667  305.0
# 2016-01-10  198.0  28.285714  169.0  24.142857  228.0  32.571429  355.0
# 2016-01-17  164.0  23.428571  181.0  25.857143  218.0  31.142857  295.0
# 2016-01-24  223.0  31.857143  228.0  32.571429  207.0  29.571429  341.0
# 2016-01-31  222.0  31.714286  243.0  34.714286  204.0  29.142857  281.0
# ...           ...        ...    ...        ...    ...        ...    ...
# 2017-05-07    0.0        NaN    0.0        NaN    0.0        NaN    0.0
# 2017-05-14    0.0        NaN    0.0        NaN    0.0        NaN    0.0
# 2017-05-21    0.0        NaN    0.0        NaN    0.0        NaN    0.0
# 2017-05-28    0.0        NaN    0.0        NaN    0.0        NaN    0.0
# 2017-06-04    0.0        NaN    0.0        NaN    0.0        NaN    0.0
#
#
# ...

# %%
weekly.agg(["sum","mean","max"])
# Out:
#             rest1                   rest2                   rest3             \
#               sum       mean   max    sum       mean   max    sum       mean
# date
# 2016-01-03  113.0  37.666667  65.0   95.0  31.666667  39.0  176.0  58.666667
# 2016-01-10  198.0  28.285714  79.0  169.0  24.142857  44.0  228.0  32.571429
# 2016-01-17  164.0  23.428571  60.0  181.0  25.857143  52.0  218.0  31.142857
# 2016-01-24  223.0  31.857143  59.0  228.0  32.571429  55.0  207.0  29.571429
# 2016-01-31  222.0  31.714286  57.0  243.0  34.714286  53.0  204.0  29.142857
# ...           ...        ...   ...    ...        ...   ...    ...        ...
# 2017-05-07    0.0        NaN   NaN    0.0        NaN   NaN    0.0        NaN
# 2017-05-14    0.0        NaN   NaN    0.0        NaN   NaN    0.0        NaN
# 2017-05-21    0.0        NaN   NaN    0.0        NaN   NaN    0.0        NaN
# 2017-05-28    0.0        NaN   NaN    0.0        NaN   NaN    0.0        NaN
# ...
