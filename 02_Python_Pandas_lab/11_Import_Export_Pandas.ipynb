# %%
import pandas as pd

# %%
# we can read from URL   pd.read_csv(url)

# %%
df=pd.read_csv("SampleSuperstore.csv",encoding='latin-1')

# %%
df.head(2).to_dict()
# Out:
# {'Row ID': {0: 1, 1: 2},
#  'Order ID': {0: 'US-2019-103800', 1: 'US-2019-112326'},
#  'Order Date': {0: '03-01-2019', 1: '04-01-2019'},
#  'Ship Date': {0: '07-01-2019', 1: '08-01-2019'},
#  'Ship Mode': {0: 'Standard Class', 1: 'Standard Class'},
#  'Customer ID': {0: 'DP-13000', 1: 'PO-19195'},
#  'Customer Name': {0: 'Darren Powers', 1: 'Phillina Ober'},
#  'Segment': {0: 'Consumer', 1: 'Home Office'},
#  'Country/Region': {0: 'United States', 1: 'United States'},
#  'City': {0: 'Houston', 1: 'Naperville'},
#  'State/Province': {0: 'Texas', 1: 'Illinois'},
#  'Postal Code': {0: '77095', 1: '60540'},
#  'Region': {0: 'Central', 1: 'Central'},
#  'Product ID': {0: 'OFF-PA-10000174', 1: 'OFF-BI-10004094'},
#  'Category': {0: 'Office Supplies', 1: 'Office Supplies'},
#  'Sub-Category': {0: 'Paper', 1: 'Binders'},
#  'Product Name': {0: 'Message Book, Wirebound, Four 5 1/2" X 4" Forms/Pg., 200 Dupl. Sets/Book',
#   1: 'GBC Standard Plastic Binding Systems Combs'},
# ...

# %%
df.head(2).to_excel('SampleSuperstore.xlsx')

# %%
df[["Order ID","Sales"]].head(2).to_excel('SampleSuperstore.xlsx')

# %%
df1=pd.read_excel('SampleSuperstore.xlsx')

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df1
# Out:
#    Unnamed: 0        Order ID   Sales
# 0           0  US-2019-103800  16.448
# 1           1  US-2019-112326   3.540

# %%
pd.read_excel('SampleSuperstore.xlsx')
# Out:
#    Unnamed: 0        Order ID   Sales
# 0           0  US-2019-103800  16.448
# 1           1  US-2019-112326   3.540

# %%
df1.to_html('SampleSuperstoreh.html')

# %%
df1
# Out:
#    Unnamed: 0        Order ID   Sales
# 0           0  US-2019-103800  16.448
# 1           1  US-2019-112326   3.540

# %%
df2=pd.read_html('SampleSuperstoreh.html')

# %%
df2
# Out:
# [   Unnamed: 0.1  Unnamed: 0        Order ID   Sales
#  0             0           0  US-2019-103800  16.448
#  1             1           1  US-2019-112326   3.540]

# %%
df.to_json('SampleSuperJson.json')

# %%
df3=pd.read_json('SampleSuperJson.json')

# %%
df3
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0           1  US-2019-103800  03-01-2019  07-01-2019  Standard Class
# 1           2  US-2019-112326  04-01-2019  08-01-2019  Standard Class
# 2           3  US-2019-112326  04-01-2019  08-01-2019  Standard Class
# 3           4  US-2019-112326  04-01-2019  08-01-2019  Standard Class
# 4           5  US-2019-141817  05-01-2019  12-01-2019  Standard Class
# ...       ...             ...         ...         ...             ...
# 10189   10190  US-2022-143259  30-12-2022  03-01-2023  Standard Class
# 10190   10191  US-2022-115427  30-12-2022  03-01-2023  Standard Class
# 10191   10192  US-2022-156720  30-12-2022  03-01-2023  Standard Class
# 10192   10193  US-2022-143259  30-12-2022  03-01-2023  Standard Class
# 10193   10194  CA-2022-143500  30-12-2022  03-01-2023  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# ...
