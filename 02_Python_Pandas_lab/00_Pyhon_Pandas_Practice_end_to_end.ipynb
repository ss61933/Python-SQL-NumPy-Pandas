# %%
import pandas as pd

# %%
pdata=pd.read_csv("SampleSuperstore.csv" ,encoding='latin-1')

# %%
pdata
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0           1  US-2019-103800  03-01-2019  07-01-2019  Standard Class
# 1           2  US-2019-112326  04-01-2019  08-01-2019  Standard Class
# 2           3  US-2019-112326  04-01-2019  08-01-2019  Standard Class
# 3           4  US-2019-112326  04-01-2019  08-01-2019  Standard Class
# 4           5  US-2019-141817  05-01-2019  12-01-2019  Standard Class
# ...       ...             ...         ...         ...             ...
# 10189   10190  US-2022-143259  30-12-2022  03-01-2023  Standard Class
# 10190   10191  US-2022-115427  30-12-2022  03-01-2023  Standard Class
# 10191   10192  US-2022-156720  30-12-2022  03-01-2023  Standard Class
# 10192   10193  US-2022-143259  30-12-2022  03-01-2023  Standard Class
# 10193   10194  CA-2022-143500  30-12-2022  03-01-2023  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# ...

# %%
pdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  object
#  3   Ship Date       10194 non-null  object
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
#  16  Product Name    10194 non-null  object
# ...

# %%
pdata.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Country/Region     object
# City               object
# State/Province     object
# Postal Code        object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# dtype: object

# %%
pdata.describe()
# Out:
#              Row ID         Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000  10194.000000
# mean    5097.500000    228.225854      3.791838      0.155385     28.673417
# std     2942.898656    619.906839      2.228317      0.206249    232.465115
# min        1.000000      0.444000      1.000000      0.000000  -6599.978000
# 25%     2549.250000     17.220000      2.000000      0.000000      1.760800
# 50%     5097.500000     53.910000      3.000000      0.200000      8.690000
# 75%     7645.750000    209.500000      5.000000      0.200000     29.297925
# max    10194.000000  22638.480000     14.000000      0.800000   8399.976000

# %%
#Change data Type for Sales as int

# %%
pdata["Sales"]=pdata["Sales"].astype(int)

# %%
pdata.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Country/Region     object
# City               object
# State/Province     object
# Postal Code        object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales               int32
# Quantity            int64
# Discount          float64
# Profit            float64
# dtype: object

# %%
pdata["Sales"].max()
# Out:
# 22638

# %%
pdata["Sales"].mean() # get average sales
# Out:
# 227.63655091230135

# %%
pdata[["Order ID","Sales"]].sort_values("Sales", ascending=False).head(5)
# Out:
#             Order ID  Sales
# 226   US-2019-145317  22638
# 5894  US-2021-118689  17499
# 7255  US-2022-140151  13999
# 9171  US-2022-127180  11199
# 9517  US-2022-166709  10499

# %%
type(pdata["Order ID"]) # Individual columns in data frame is of type Series
# Out:
# pandas.core.series.Series

# %%
SAlesAbove13k=pdata[pdata["Sales"]>13000]

# %%
SAlesAbove13k
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 226      227  US-2019-145317  18-03-2019  23-03-2019  Standard Class
# 5894    5895  US-2021-118689  02-10-2021  09-10-2021  Standard Class
# 7255    7256  US-2022-140151  23-03-2022  25-03-2022     First Class
#
#      Customer ID Customer Name      Segment Country/Region          City  ...  \
# 226     SM-20320   Sean Miller  Home Office  United States  Jacksonville  ...
# 5894    TC-20980  Tamara Chand    Corporate  United States     Lafayette  ...
# 7255    RB-19360  Raymond Buch     Consumer  United States       Seattle  ...
#
#      Postal Code   Region       Product ID    Category Sub-Category  \
# 226        32216    South  TEC-MA-10002412  Technology     Machines
# 5894       47905  Central  TEC-CO-10004722  Technology      Copiers
# 7255       98115     West  TEC-CO-10004722  Technology      Copiers
#
#                                            Product Name  Sales  Quantity  \
# ...

# %%
Filter1=pdata["Row ID"].isin([226,7255])

# %%
pdata[Filter1]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 225      226  US-2019-131275  18-03-2019  24-03-2019  Standard Class
# 7254    7255  US-2022-136511  23-03-2022  25-03-2022    Second Class
#
#      Customer ID     Customer Name      Segment Country/Region           City  \
# 225     SC-20050  Sample Company A  Home Office  United States        Burbank
# 7254    MZ-17515         Mary Zewe    Corporate  United States  New York City
#
#       ... Postal Code Region       Product ID         Category Sub-Category  \
# 225   ...       91505   West  TEC-MA-10001148       Technology     Machines
# 7254  ...       10011   East  OFF-SU-10003505  Office Supplies     Supplies
#
#                                       Product Name Sales  Quantity  Discount  \
# 225   Swingline SM12-08 MicroCut Jam Free Shredder  1279         4       0.2
# 7254                Premier Electric Letter Opener   347         3       0.0
#
#         Profit
# 225   415.9896
# 7254   17.3790
#
# ...

# %%
Orderrow225=pdata[(pdata["Segment"]=="Home Office") & (pdata["Sales"]>7500)]

# %%
Orderrow225
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 226      227  US-2019-145317  18-03-2019  23-03-2019  Standard Class
# 9171    9172  US-2022-127180  22-10-2022  24-10-2022     First Class
#
#      Customer ID Customer Name      Segment Country/Region           City  \
# 226     SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 9171    TA-21385  Tom Ashbrook  Home Office  United States  New York City
#
#       ... Postal Code Region       Product ID    Category Sub-Category  \
# 226   ...       32216  South  TEC-MA-10002412  Technology     Machines
# 9171  ...       10024   East  TEC-CO-10004722  Technology      Copiers
#
#                                            Product Name  Sales  Quantity  \
# 226   Cisco TelePresence System EX90 Videoconferenci...  22638         6
# 9171              Canon imageCLASS 2200 Advanced Copier  11199         4
#
#       Discount     Profit
# 226        0.5 -1811.0784
# 9171       0.2  3919.9888
#
# ...

# %%
Orderrow225=pdata[(pdata["Segment"]=="Home Office") & (pdata["Customer ID"].isin(["ME-17320","ME-17320"])) ]

# %%
Orderrow225
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 5          6  US-2019-167199  06-01-2019  10-01-2019  Standard Class
# 6          7  US-2019-167199  06-01-2019  10-01-2019  Standard Class
# 8          9  US-2019-167199  06-01-2019  10-01-2019  Standard Class
# 9         10  US-2019-167199  06-01-2019  10-01-2019  Standard Class
# 10        11  US-2019-167199  06-01-2019  10-01-2019  Standard Class
# 12        13  US-2019-167199  06-01-2019  10-01-2019  Standard Class
# 13        14  US-2019-167199  06-01-2019  10-01-2019  Standard Class
# 2721    2722  US-2020-144302  19-06-2020  23-06-2020  Standard Class
# 4513    4514  US-2021-152555  29-03-2021  02-04-2021    Second Class
# 4518    4519  US-2021-152555  29-03-2021  02-04-2021    Second Class
# 4520    4521  US-2021-152555  29-03-2021  02-04-2021    Second Class
# 4549    4550  US-2021-159142  04-04-2021  05-04-2021     First Class
# 4552    4553  US-2021-159142  04-04-2021  05-04-2021     First Class
# ...

# %%
Orderrow225.count()
# Out:
# Row ID            22
# Order ID          22
# Order Date        22
# Ship Date         22
# Ship Mode         22
# Customer ID       22
# Customer Name     22
# Segment           22
# Country/Region    22
# City              22
# State/Province    22
# Postal Code       22
# Region            22
# Product ID        22
# Category          22
# Sub-Category      22
# Product Name      22
# Sales             22
# Quantity          22
# Discount          22
# Profit            22
# dtype: int64

# %%
Orderrow225["Order ID"].count()
# Out:
# 22

# %%
pdata["Order ID"].max()
# Out:
# 'US-2022-169999'

# %%
CID=pdata.loc[pdata["Order ID"]=='US-2022-169999', "Customer ID"] # So loc here understands cond before comma is filter and after is column to select

# %%
CID
# Out:
# 7933    JS-15685
# 7937    JS-15685
# Name: Customer ID, dtype: object

# %%
CID=pdata.loc[pdata["Order ID"]=='US-2022-169999']

# %%
CID[["Customer ID","Order ID"]]
# Out:
#      Customer ID        Order ID
# 7933    JS-15685  US-2022-169999
# 7937    JS-15685  US-2022-169999

# %%
pdata.iloc[1:3,1:3] # Limit rows and columns
# Out:
#          Order ID  Order Date
# 1  US-2019-112326  04-01-2019
# 2  US-2019-112326  04-01-2019

# %%
##PLoting with pandas

# %%
pdata["Profit"].head(5).plot.bar(x="Order ID")
# Out:
# <AxesSubplot:>

# %%
pdata.plot().scatter(x="Sales",y="Quantity",alpha=0.5)
